# %% [markdown]
# # Python Overview
#
# This notebook will cover the following topics:
#
# 1.   List item
# 2.   List item

# %% [markdown]
# # List item 1

# %% [markdown]
# Text about List item 1

# %%
#Code about list item 1

# %%
#Code about list item 1

# %%
#Code about list item 1

# %% [markdown]
# #Acknowledgements
#
# List here all references/contact of which you based your material.
